# %% [markdown]
# Get some test data from the rtlsdr

# %%
from pylab import *
from rtlsdr import *

sdr = RtlSdr()

# configure device
sdr.sample_rate = 2.4e6
sdr.center_freq = 90.1e6
sdr.gain = 41

# %% [markdown]
# Plot the data

# %%
# read 1 second of samples
samples = sdr.read_samples(1 * sdr.sample_rate)

# use matplotlib to estimate and plot the PSD
psd(samples, NFFT=1024, Fs=sdr.sample_rate/1e6, Fc=sdr.center_freq/1e6)
xlabel('Frequency (MHz)')
ylabel('Relative power (dB)')
title('Frequency domain')

show()

# %%
from replay import get_samples, play_samples, filter_samples
s = get_samples(90.1e6, 0.1)
psd(s, NFFT=1024, Fs=sdr.sample_rate/1e6, Fc=sdr.center_freq/1e6)
xlabel('Frequency (MHz)')
ylabel('Relative power (dB)')
title('Frequency domain')

show()

# %% [markdown]
# Print the Real parts of the samples

# %%
flts, _ = filter_samples(s)
psd(flts, NFFT=1024, Fs=sdr.sample_rate/1e6, Fc=sdr.center_freq/1e6)
xlabel('Frequency (MHz)')
ylabel('Relative power (dB)')
title('Frequency domain')

show()

# %%
sdr.close()
